# %%
from typing import TypedDict

class SocialMediaState(TypedDict):

    user_query: str

    trend_report: dict

    company_context: str

    strategy: dict

    generated_content: dict

    compliance_review: dict

# %%
def trend_node(state: SocialMediaState):

    response = trend_agent.invoke(
        {
            "messages": [
                {
                    "role": "user",
                    "content": state["user_query"]
                }
            ]
        }
    )

    return {
        "trend_report": response["structured_response"]
    }
